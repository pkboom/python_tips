# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn')

data = pd.read_csv('data/scatter.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']
# view_count, likes, ratio
# Out:
# /var/folders/gq/x0p5x61x59b0l02wwlvcqk_h0000gn/T/ipykernel_1994/2845670901.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.scatter(view_count, likes, c=ratio, cmap='summer',
            edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.show()

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

x_added_1 = np.array(x) + 1

plt.scatter(x, y, s=100, c='green', edgecolor='black', linewidth=1, alpha=0.75)
plt.scatter(x_added_1, y, s=50, c='green', marker='x')

# %%
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5] # intensity of color

plt.scatter(x, y, s=100, c=colors, edgecolor='black', linewidth=1, alpha=0.75)
plt.scatter(x_added_1, y, s=100, c=colors, cmap='Greens',
            edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Satisfaction')

# %%
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

plt.scatter(x, y, s=sizes, c=colors, cmap='Greens',
            edgecolor='black', linewidth=1, alpha=0.75)
